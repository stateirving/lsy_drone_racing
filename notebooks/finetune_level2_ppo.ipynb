# %% [markdown]
# # Level2 PPO Fine-tuning Notebook
#
# 这个 notebook 从已有 checkpoint 加载模型权重，用新的 reward 配置做低学习率微调。checkpoint 不包含 optimizer 状态，因此这不是精确续训，optimizer 会重新初始化。
#
# 推荐顺序：
#
# 1. 检查 kernel 和仓库路径。
# 2. 跑 `debug_rollout` 看 observation 和 reward 分量。
# 3. 跑很小的 smoke train，确认 PPO 更新不报错。
# 4. 调大 `num_envs` / `total_timesteps` 正式微调。
# 5. 用不渲染的本地评估循环快速看 checkpoint 行为。

# %%
from pathlib import Path
import os
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / "pyproject.toml").exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
sys.path.insert(0, str(ROOT))

print("repo:", ROOT)
print("python:", sys.executable)
# Out:
# repo: /home/miao/repo/lsy_drone_racing
# python: /home/miao/repo/lsy_drone_racing/.pixi/envs/gpu/bin/python

# %% [markdown]
# 如果下面 import 失败，通常是当前 notebook kernel 没选对。`default` 环境没有 `torch`。
#
# 正式 GPU 训练请选择：
#
# ```text
# .pixi/envs/gpu/bin/python
# ```
#
# CPU debug 或没有 GPU 时可以选择：
#
# ```text
# .pixi/envs/tests/bin/python
# ```
#
# 或者在终端用 `pixi shell -e tests` 后启动 notebook。
#
#
# 如果 VS Code 仍然不显示 kernel，在项目根目录手动运行其中一个：
#
# ```bash
# pixi run -e gpu python -m ipykernel install --user --name lsy-drone-racing-gpu --display-name "LSY Drone Racing (gpu)"
# pixi run -e tests python -m ipykernel install --user --name lsy-drone-racing-tests --display-name "LSY Drone Racing (tests)"
# ```
#
# 然后重载 VS Code，再选择 `LSY Drone Racing (gpu)` 或 `LSY Drone Racing (tests)`。

# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import torch
import wandb

from lsy_drone_racing.control.train_CleanRL_ppo import (
    Agent,
    Args,
    debug_rollout,
    make_envs,
    train_ppo,
)

print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("wandb:", wandb.__version__)
# Out:
# torch: 2.8.0+cu128
# cuda available: True
# wandb: 0.25.1

# %% [markdown]
# ## 调参

# %%
CONFIG = "level2.toml"
CHECKPOINT_DIR = ROOT / "lsy_drone_racing/control/checkpoints/ppo_level2_obs1_clearance_ft"
MODEL_PATH = CHECKPOINT_DIR / "ppo_level2_obs1_clearance_ft_final.ckpt"
# 默认从已验证能够完成赛道的 100M 权重开始，避免从已陷入停滞的 obs1_90M 开始。
INITIAL_MODEL_PATH = ROOT / "lsy_drone_racing/control/checkpoints/ppo_level2_cmdtilt1p5_160M/ppo_level2_cmdtilt1p5_160M_step_100000000.ckpt"
# 如需明确继续当前 obs1，将上一行替换为：
# INITIAL_MODEL_PATH = ROOT / "lsy_drone_racing/control/checkpoints/ppo_level2_obs1/ppo_level2_obs1_step_110000000.ckpt"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
assert INITIAL_MODEL_PATH.exists(), INITIAL_MODEL_PATH

JAX_DEVICE = "gpu"
CUDA = True

WANDB_ENABLED = True
WANDB_PROJECT_NAME = "ADR-PPO-Racing"
WANDB_ENTITY = None  # 如果你们用 team，在这里填 team/entity 名称
WANDB_MODE = "online"  # 没网时可改成 "offline"

NUM_ENVS_DEBUG = 4
NUM_ENVS_TRAIN = 1024
NUM_STEPS = 32
TOTAL_TIMESTEPS_TRAIN = 50_000_000
CHECKPOINT_INTERVAL_STEPS = 5_000_000
LEARNING_RATE = 1e-4
GAMMA = 0.99
GAE_LAMBDA = 0.95
UPDATE_EPOCHS = 5
NUM_MINIBATCHES = 8
ENT_COEF = 0.02
TARGET_KL = 0.03

REWARD_KWARGS = dict(
    progress_coef=0.0,
    gate_stage_coef = 8.0,
    gate_axis_coef=12.0,
    near_gate_coef=0.0,

    gate_bonus=80.0,
    gate_back_bonus=8.0,
    finish_bonus=160.0,

    missed_gate_penalty=8.0,
    crash_penalty=50.0,

    obstacle_coef=5.0,
    obstacle_margin=0.40,
    obstacle_clearance_coef=8.0,

    timeout_penalty=80.0,
    time_penalty=0.03,

    act_coef=0.03,
    d_act_th_coef=0.15,
    d_act_xy_coef=0.15,
    cmd_tilt_coef=1.5,

    rpy_coef=1.5,
    tilt_limit_deg=30.0,
    tilt_excess_coef=20.0,

)

def build_args(**overrides):
    base = dict(
        config=CONFIG,
        cuda=CUDA,
        jax_device=JAX_DEVICE,
        wandb_project_name=WANDB_PROJECT_NAME,
        wandb_entity=WANDB_ENTITY,
        num_steps=NUM_STEPS,
        gamma=GAMMA,
        gae_lambda=GAE_LAMBDA,
        update_epochs=UPDATE_EPOCHS,
        num_minibatches=NUM_MINIBATCHES,
        n_obs=2,
        **REWARD_KWARGS,
    )
    base.update(overrides)
    return Args.create(**base)

def torch_device(args):
    return torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

MODEL_PATH
# Out:
# PosixPath('/home/miao/repo/lsy_drone_racing/lsy_drone_racing/control/checkpoints/ppo_level2_obs1_clearance_ft/ppo_level2_obs1_clearance_ft_final.ckpt')

# %% [markdown]
# ## W&B 登录
#
# 第一次运行会要求登录。不要把 API key 写进 notebook；按提示在输入框里粘贴即可。
#
# 如果你只想本地记录，把上面配置里的 `WANDB_MODE` 改成 `"offline"`。

# %%
os.environ["WANDB_MODE"] = WANDB_MODE
os.environ["WANDB_NOTEBOOK_NAME"] = str(ROOT / "notebooks/finetune_level2_ppo.ipynb")

if WANDB_ENABLED:
    if WANDB_MODE != "offline":
        wandb.login()
    print(f"W&B enabled: project={WANDB_PROJECT_NAME}, entity={WANDB_ENTITY}")
else:
    print("W&B disabled")
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/miao/.netrc.
# wandb: Currently logged in as: xiaochenmiao (xiaochenmiao-technical-university-of-munich) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# W&B enabled: project=ADR-PPO-Racing, entity=None

# %% [markdown]
# ## 1. 检查 observation / reward
#
# 这一格不会训练，只用零动作跑几步。重点看：
#
# - `obs_dim=103` 是否稳定。
# - reward 里 `progress / gate_bonus / crash / obstacle / smooth` 是否合理。
# - 是否有非有限值或一开始大量 crash。

# %%
debug_args = build_args(
    num_envs=NUM_ENVS_DEBUG,
    total_timesteps=NUM_ENVS_DEBUG * NUM_STEPS,
)

debug_rollout(
    debug_args,
    n_steps=20,
    device=torch_device(debug_args),
    jax_device=debug_args.jax_device,
)
# Out:
# /home/miao/repo/lsy_drone_racing/.pixi/envs/gpu/lib/python3.13/site-packages/jax/_src/abstract_arrays.py:135: RuntimeWarning: overflow encountered in cast
#   return literals.TypedNdArray(np.asarray(x, dtype), weak_type=False)
# [obs-debug] obs_dim=103 num_envs=4
# [obs-debug] pos_z                      slice=000:001 mean= 0.017 std= 0.007 min= 0.011 max= 0.028
# [obs-debug] vel_body                   slice=001:004 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] ang_vel                    slice=004:007 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] rotmat                     slice=007:016 mean= 0.333 std= 0.472 min=-0.079 max= 1.000
# [obs-debug] target_progress            slice=016:017 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] gate_prev_corners_body     slice=017:029 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] gate_current_corners_body  slice=029:041 mean= 0.720 std= 1.050 min=-0.795 max= 2.281
# [obs-debug] gate_next_corners_body     slice=041:053 mean= 1.235 std= 1.077 min=-0.346 max= 2.839
# [obs-debug] obstacles_body             slice=053:065 mean= 0.685 std= 1.189 min=-1.680 max= 2.670
# [obs-debug] gates_visited              slice=065:069 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] obstacles_visited          slice=069:073 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] last_action                slice=073:077 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] history                    slice=077:103 mean= 0.020 std= 0.545 min=-1.599 max= 1.000
# [debug-rollout] obs_shape=(4, 103) action_shape=(4,)
# [reward-debug] step=1 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.039 progress=-0.000 gate_axis_progress=-0.000 gate_stage_progress=-0.005 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.004 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=1/20 reward_mean=-0.039 reward_min=-0.042 reward_max=-0.036 done=0/4
# [reward-debug] step=2 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.049 progress=-0.000 gate_axis_progress=-0.000 gate_stage_progress=-0.015 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.004 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=2/20 reward_mean=-0.049 reward_min=-0.052 reward_max=-0.046 done=0/4
# [reward-debug] step=3 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.052 progress=-0.000 gate_axis_progress=-0.000 gate_stage_progress=-0.019 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.003 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=3/20 reward_mean=-0.052 reward_min=-0.058 reward_max=-0.048 done=0/4
# [reward-debug] step=4 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.040 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=-0.008 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.002 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=4/20 reward_mean=-0.040 reward_min=-0.055 reward_max=-0.031 done=0/4
# [reward-debug] step=5 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.033 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=-0.002 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.001 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=5/20 reward_mean=-0.033 reward_min=-0.039 reward_max=-0.030 done=0/4
# [reward-debug] step=6 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.031 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=-0.000 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.001 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=6/20 reward_mean=-0.031 reward_min=-0.031 reward_max=-0.030 done=0/4
# [reward-debug] step=7 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.031 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=-0.000 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=7/20 reward_mean=-0.031 reward_min=-0.031 reward_max=-0.030 done=0/4
# [reward-debug] step=8 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.031 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=-0.000 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=8/20 reward_mean=-0.031 reward_min=-0.031 reward_max=-0.030 done=0/4
# [reward-debug] step=9 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.030 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=0.000 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=9/20 reward_mean=-0.030 reward_min=-0.031 reward_max=-0.029 done=0/4
# [reward-debug] step=10 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.029 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=0.001 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=10/20 reward_mean=-0.029 reward_min=-0.030 reward_max=-0.028 done=0/4
# [reward-debug] step=11 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.029 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=0.002 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=11/20 reward_mean=-0.029 reward_min=-0.030 reward_max=-0.028 done=0/4
# [reward-debug] step=12 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.028 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=0.002 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=12/20 reward_mean=-0.028 reward_min=-0.029 reward_max=-0.027 done=0/4
# [reward-debug] step=13 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.027 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=0.003 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=13/20 reward_mean=-0.027 reward_min=-0.028 reward_max=-0.025 done=0/4
# [reward-debug] step=14 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.026 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=0.004 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=14/20 reward_mean=-0.026 reward_min=-0.027 reward_max=-0.025 done=0/4
# [reward-debug] step=15 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.025 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=0.005 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=15/20 reward_mean=-0.025 reward_min=-0.027 reward_max=-0.024 done=0/4
# [reward-debug] step=16 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.024 progress=0.000 gate_axis_progress=0.000 gate_stage_progress=0.006 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=16/20 reward_mean=-0.024 reward_min=-0.026 reward_max=-0.022 done=0/4
# [reward-debug] step=17 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.024 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=0.006 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=17/20 reward_mean=-0.024 reward_min=-0.025 reward_max=-0.022 done=0/4
# [reward-debug] step=18 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.023 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=0.007 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=18/20 reward_mean=-0.023 reward_min=-0.024 reward_max=-0.021 done=0/4
# [reward-debug] step=19 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.023 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=0.007 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=19/20 reward_mean=-0.023 reward_min=-0.024 reward_max=-0.020 done=0/4
# [reward-debug] step=20 done=0/4 target_gate=[4, 0, 0, 0] reward=-0.023 progress=0.000 gate_axis_progress=-0.000 gate_stage_progress=0.007 gate_front=0.000 gate_plane=0.000 gate_back=0.000 near_gate=0.000 gate_bonus=0.000 finish_bonus=0.000 missed_gate=-0.000 wrong_side=-0.000 crash=-0.000 action=-0.000 cmd_tilt=-0.000 smooth=-0.000 tilt=-0.000 tilt_excess=-0.000 obstacle=-0.000 obstacle_clearance=0.000 timeout=-0.000 time=-0.030
# [debug-rollout] step=20/20 reward_mean=-0.023 reward_min=-0.025 reward_max=-0.019 done=0/4

# %% [markdown]
# ## 2. 手动创建环境看 shape
#
# 如果你改了 `RaceObservation`，先跑这个确认 shape 和 action space。

# %%
shape_args = build_args(num_envs=NUM_ENVS_DEBUG)
envs = make_envs(
    config=shape_args.config,
    num_envs=shape_args.num_envs,
    jax_device=shape_args.jax_device,
    torch_device=torch_device(shape_args),
    coefs=REWARD_KWARGS | {"n_obs": shape_args.n_obs},
    debug_obs=True,
    debug_reward_every=0,
)
obs, info = envs.reset(seed=shape_args.seed)
print("obs shape:", tuple(obs.shape))
print("single obs space:", envs.single_observation_space)
print("single action space:", envs.single_action_space)
envs.close()
# Out:
# [obs-debug] obs_dim=103 num_envs=4
# [obs-debug] pos_z                      slice=000:001 mean= 0.017 std= 0.007 min= 0.011 max= 0.028
# [obs-debug] vel_body                   slice=001:004 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] ang_vel                    slice=004:007 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] rotmat                     slice=007:016 mean= 0.333 std= 0.472 min=-0.079 max= 1.000
# [obs-debug] target_progress            slice=016:017 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] gate_prev_corners_body     slice=017:029 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] gate_current_corners_body  slice=029:041 mean= 0.720 std= 1.050 min=-0.795 max= 2.281
# [obs-debug] gate_next_corners_body     slice=041:053 mean= 1.235 std= 1.077 min=-0.346 max= 2.839
# [obs-debug] obstacles_body             slice=053:065 mean= 0.685 std= 1.189 min=-1.680 max= 2.670
# [obs-debug] gates_visited              slice=065:069 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] obstacles_visited          slice=069:073 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] last_action                slice=073:077 mean= 0.000 std= 0.000 min= 0.000 max= 0.000
# [obs-debug] history                    slice=077:103 mean= 0.020 std= 0.545 min=-1.599 max= 1.000
# obs shape: (4, 103)
# single obs space: Box(-inf, inf, (103,), float32)
# single action space: Box(-1.0, 1.0, (4,), float32)

# %% [markdown]
# ## 3. PPO fine-tune smoke test
#
# 这个只微调几十步，目标是确认 checkpoint 权重加载、rollout、GAE、反传和保存都不报错。

# %%
smoke_args = build_args(
    num_envs=2,
    num_steps=8,
    total_timesteps=64,
    jax_device="cpu",
    cuda=False,
)

train_ppo(
    smoke_args,
    model_path=Path("/tmp/ppo_level2_finetune_notebook_smoke.ckpt"),
    device=torch_device(smoke_args),
    jax_device=smoke_args.jax_device,
    wandb_enabled=False,
    initial_model_path=INITIAL_MODEL_PATH,
)
# Out:
# Training on device: cpu | Environment device: cpu
# initialized agent weights from /home/miao/repo/lsy_drone_racing/lsy_drone_racing/control/checkpoints/ppo_level2_cmdtilt1p5_160M/ppo_level2_cmdtilt1p5_160M_step_100000000.ckpt; optimizer starts fresh
# Iter 1/4 took 2.57 seconds
# Iter 2/4 took 0.29 seconds
# Iter 3/4 took 0.37 seconds
# Iter 4/4 took 0.38 seconds
# Training for 64 steps took 6.65 seconds.
# model saved to /tmp/ppo_level2_finetune_notebook_smoke.ckpt
# []

# %% [markdown]
# ## 4. 正式微调

# %%
train_args = build_args(
    num_envs=NUM_ENVS_TRAIN,
    num_steps=NUM_STEPS,
    total_timesteps=TOTAL_TIMESTEPS_TRAIN,
    learning_rate=LEARNING_RATE,
    ent_coef=ENT_COEF,
    target_kl=TARGET_KL,
)

if WANDB_ENABLED and wandb.run is not None:
    wandb.finish()

train_ppo(
    train_args,
    model_path=MODEL_PATH,
    device=torch_device(train_args),
    jax_device=train_args.jax_device,
    wandb_enabled=WANDB_ENABLED,
    checkpoint_dir=CHECKPOINT_DIR,
    checkpoint_interval=CHECKPOINT_INTERVAL_STEPS,
    initial_model_path=INITIAL_MODEL_PATH,
)

print("saved:", MODEL_PATH)
if WANDB_ENABLED and wandb.run is not None:
    print("wandb:", wandb.run.url)
    wandb.finish()
# Out:
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/home/miao/repo/lsy_drone_racing/wandb/run-20260604_150257-ukdz72dt</code>
# Syncing run <strong><a href='https://wandb.ai/xiaochenmiao-technical-university-of-munich/ADR-PPO-Racing/runs/ukdz72dt' target="_blank">dashing-music-32</a></strong> to <a href='https://wandb.ai/xiaochenmiao-technical-university-of-munich/ADR-PPO-Racing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/xiaochenmiao-technical-university-of-munich/ADR-PPO-Racing' target="_blank">https://wandb.ai/xiaochenmiao-technical-university-of-munich/ADR-PPO-Racing</a>
#  View run at <a href='https://wandb.ai/xiaochenmiao-technical-university-of-munich/ADR-PPO-Racing/runs/ukdz72dt' target="_blank">https://wandb.ai/xiaochenmiao-technical-university-of-munich/ADR-PPO-Racing/runs/ukdz72dt</a>
# Training on device: cuda | Environment device: gpu
# /home/miao/repo/lsy_drone_racing/.pixi/envs/gpu/lib/python3.13/site-packages/jax/_src/abstract_arrays.py:135: RuntimeWarning: overflow encountered in cast
#   return literals.TypedNdArray(np.asarray(x, dtype), weak_type=False)
# initialized agent weights from /home/miao/repo/lsy_drone_racing/lsy_drone_racing/control/checkpoints/ppo_level2_cmdtilt1p5_160M/ppo_level2_cmdtilt1p5_160M_step_100000000.ckpt; optimizer starts fresh
# Iter 1/1525 took 13.78 seconds
# Iter 2/1525 took 1.94 seconds
# Iter 3/1525 took 2.05 seconds
# Iter 4/1525 took 1.91 seconds
# Iter 5/1525 took 1.90 seconds
# Iter 6/1525 took 2.01 seconds
# Iter 7/1525 took 2.00 seconds
# Iter 8/1525 took 2.16 seconds
# Iter 9/1525 took 1.97 seconds
# Iter 10/1525 took 1.92 seconds
# Iter 11/1525 took 2.17 seconds
# Iter 12/1525 took 2.25 seconds
# Iter 13/1525 took 2.55 seconds
# Iter 14/1525 took 2.52 seconds
# Iter 15/1525 took 2.19 seconds
# Iter 16/1525 took 2.00 seconds
# Iter 17/1525 took 2.10 seconds
# Iter 18/1525 took 1.95 seconds
# Iter 19/1525 took 2.17 seconds
# Iter 20/1525 took 2.15 seconds
# Iter 21/1525 took 2.30 seconds
# Iter 22/1525 took 2.44 seconds
# Iter 23/1525 took 2.24 seconds
# Iter 24/1525 took 2.24 seconds
# Iter 25/1525 took 2.19 seconds
# Iter 26/1525 took 2.74 seconds
# Iter 27/1525 took 3.12 seconds
# Iter 28/1525 took 2.29 seconds
# Iter 29/1525 took 2.13 seconds
# Iter 30/1525 took 2.18 seconds
# Iter 31/1525 took 2.19 seconds
# Iter 32/1525 took 2.16 seconds
# Iter 33/1525 took 2.19 seconds
# Iter 34/1525 took 2.13 seconds
# Iter 35/1525 took 2.38 seconds
# Iter 36/1525 took 2.49 seconds
# Iter 37/1525 took 2.06 seconds
# Iter 38/1525 took 2.08 seconds
# Iter 39/1525 took 2.03 seconds
# Iter 40/1525 took 2.41 seconds
# Iter 41/1525 took 2.32 seconds
# Iter 42/1525 took 2.11 seconds
# Iter 43/1525 took 2.08 seconds
# Iter 44/1525 took 2.14 seconds
# Iter 45/1525 took 2.53 seconds
# Iter 46/1525 took 2.26 seconds
# Iter 47/1525 took 2.10 seconds
# Iter 48/1525 took 2.10 seconds
# Iter 49/1525 took 2.19 seconds
# Iter 50/1525 took 2.08 seconds
# Iter 51/1525 took 2.18 seconds
# Iter 52/1525 took 2.15 seconds
# Iter 53/1525 took 2.18 seconds
# Iter 54/1525 took 2.73 seconds
# Iter 55/1525 took 2.36 seconds
# Iter 56/1525 took 2.19 seconds
# Iter 57/1525 took 2.42 seconds
# Iter 58/1525 took 2.53 seconds
# Iter 59/1525 took 2.59 seconds
# Iter 60/1525 took 2.28 seconds
# Iter 61/1525 took 2.20 seconds
# Iter 62/1525 took 2.53 seconds
# Iter 63/1525 took 2.29 seconds
# Iter 64/1525 took 2.27 seconds
# Iter 65/1525 took 2.23 seconds
# Iter 66/1525 took 1.97 seconds
# Iter 67/1525 took 2.36 seconds
# Iter 68/1525 took 2.77 seconds
# Iter 69/1525 took 2.15 seconds
# Iter 70/1525 took 2.00 seconds
# Iter 71/1525 took 2.09 seconds
# Iter 72/1525 took 2.70 seconds
# Iter 73/1525 took 2.39 seconds
# Iter 74/1525 took 2.00 seconds
# Iter 75/1525 took 2.03 seconds
# Iter 76/1525 took 2.15 seconds
# Iter 77/1525 took 2.03 seconds
# Iter 78/1525 took 1.96 seconds
# Iter 79/1525 took 2.06 seconds
# Iter 80/1525 took 2.25 seconds
# Iter 81/1525 took 2.48 seconds
# Iter 82/1525 took 2.39 seconds
# Iter 83/1525 took 2.08 seconds
# Iter 84/1525 took 2.15 seconds
# Iter 85/1525 took 2.30 seconds
# Iter 86/1525 took 2.58 seconds
# Iter 87/1525 took 2.27 seconds
# Iter 88/1525 took 2.23 seconds
# Iter 89/1525 took 2.08 seconds
# Iter 90/1525 took 2.22 seconds
# Iter 91/1525 took 2.03 seconds
# Iter 92/1525 took 2.01 seconds
# Iter 93/1525 took 2.17 seconds
# Iter 94/1525 took 2.14 seconds
# Iter 95/1525 took 2.41 seconds
# Iter 96/1525 took 2.30 seconds
# Iter 97/1525 took 2.09 seconds
# Iter 98/1525 took 2.09 seconds
# Iter 99/1525 took 2.03 seconds
# Iter 100/1525 took 2.52 seconds
# Iter 101/1525 took 2.29 seconds
# Iter 102/1525 took 2.10 seconds
# Iter 103/1525 took 2.14 seconds
# Iter 104/1525 took 2.41 seconds
# Iter 105/1525 took 2.08 seconds
# Iter 106/1525 took 2.11 seconds
# Iter 107/1525 took 2.00 seconds
# Iter 108/1525 took 2.01 seconds
# Iter 109/1525 took 2.29 seconds
# Iter 110/1525 took 2.36 seconds
# Iter 111/1525 took 2.00 seconds
# Iter 112/1525 took 1.96 seconds
# Iter 113/1525 took 2.12 seconds
# Iter 114/1525 took 2.40 seconds
# Iter 115/1525 took 2.34 seconds
# Iter 116/1525 took 2.04 seconds
# Iter 117/1525 took 2.03 seconds
# Iter 118/1525 took 2.21 seconds
# Iter 119/1525 took 2.67 seconds
# Iter 120/1525 took 2.34 seconds
# Iter 121/1525 took 2.06 seconds
# Iter 122/1525 took 2.14 seconds
# Iter 123/1525 took 2.21 seconds
# Iter 124/1525 took 2.07 seconds
# Iter 125/1525 took 2.12 seconds
# Iter 126/1525 took 2.06 seconds
# Iter 127/1525 took 2.36 seconds
# Iter 128/1525 took 2.73 seconds
# Iter 129/1525 took 2.55 seconds
# Iter 130/1525 took 2.16 seconds
# Iter 131/1525 took 2.17 seconds
# Iter 132/1525 took 2.31 seconds
# Iter 133/1525 took 2.17 seconds
# Iter 134/1525 took 2.19 seconds
# Iter 135/1525 took 2.16 seconds
# Iter 136/1525 took 2.18 seconds
# Iter 137/1525 took 2.85 seconds
# Iter 138/1525 took 2.55 seconds
# Iter 139/1525 took 2.60 seconds
# Iter 140/1525 took 2.24 seconds
# Iter 141/1525 took 2.76 seconds
# Iter 142/1525 took 2.39 seconds
# Iter 143/1525 took 2.25 seconds
# Iter 144/1525 took 2.13 seconds
# Iter 145/1525 took 2.38 seconds
# Iter 146/1525 took 2.83 seconds
# Iter 147/1525 took 2.20 seconds
# Iter 148/1525 took 2.03 seconds
# Iter 149/1525 took 2.48 seconds
# Iter 150/1525 took 2.77 seconds
# Iter 151/1525 took 2.20 seconds
# Iter 152/1525 took 2.41 seconds
# Iter 153/1525 took 2.08 seconds
# checkpoint saved to /home/miao/repo/lsy_drone_racing/lsy_drone_racing/control/checkpoints/ppo_level2_obs1_clearance_ft/ppo_level2_obs1_clearance_ft_step_005000000.ckpt at global_step=5013504
# Iter 154/1525 took 2.46 seconds
# Iter 155/1525 took 2.49 seconds
# Iter 156/1525 took 2.53 seconds
# Iter 157/1525 took 2.10 seconds
# Iter 158/1525 took 2.30 seconds
# Iter 159/1525 took 2.57 seconds
# Iter 160/1525 took 2.33 seconds
# Iter 161/1525 took 2.18 seconds
# Iter 162/1525 took 2.33 seconds
# Iter 163/1525 took 2.31 seconds
# Iter 164/1525 took 2.12 seconds
# Iter 165/1525 took 2.18 seconds
# Iter 166/1525 took 2.06 seconds
# Iter 167/1525 took 2.32 seconds
# Iter 168/1525 took 2.75 seconds
# Iter 169/1525 took 2.47 seconds
# Iter 170/1525 took 2.21 seconds
# Iter 171/1525 took 2.28 seconds
# Iter 172/1525 took 2.76 seconds
# Iter 173/1525 took 2.34 seconds
# Iter 174/1525 took 2.27 seconds
# Iter 175/1525 took 2.15 seconds
# Iter 176/1525 took 2.56 seconds
# Iter 177/1525 took 2.29 seconds
# Iter 178/1525 took 2.22 seconds
# Iter 179/1525 took 2.11 seconds
# Iter 180/1525 took 2.13 seconds
# Iter 181/1525 took 2.63 seconds
# Iter 182/1525 took 2.21 seconds
# Iter 183/1525 took 2.05 seconds
# Iter 184/1525 took 2.02 seconds
# Iter 185/1525 took 2.49 seconds
# Iter 186/1525 took 2.45 seconds
# Iter 187/1525 took 2.12 seconds
# Iter 188/1525 took 2.06 seconds
# Iter 189/1525 took 2.10 seconds
# Iter 190/1525 took 2.61 seconds
# Iter 191/1525 took 2.45 seconds
# Iter 192/1525 took 2.26 seconds
# Iter 193/1525 took 2.25 seconds
# Iter 194/1525 took 2.49 seconds
# Iter 195/1525 took 2.25 seconds
# Iter 196/1525 took 2.46 seconds
# Iter 197/1525 took 2.52 seconds
# Iter 198/1525 took 2.67 seconds
# Iter 199/1525 took 2.56 seconds
# Iter 200/1525 took 2.21 seconds
# Iter 201/1525 took 2.27 seconds
# Iter 202/1525 took 2.23 seconds
# Iter 203/1525 took 2.69 seconds
# Iter 204/1525 took 2.21 seconds
# Iter 205/1525 took 2.10 seconds
# Iter 206/1525 took 2.22 seconds
# Iter 207/1525 took 2.49 seconds
# Iter 208/1525 took 2.17 seconds
# Iter 209/1525 took 2.20 seconds
# Iter 210/1525 took 2.23 seconds
# Iter 211/1525 took 2.32 seconds
# Iter 212/1525 took 2.83 seconds
# Iter 213/1525 took 2.46 seconds
# Iter 214/1525 took 2.26 seconds
# Iter 215/1525 took 2.21 seconds
# Iter 216/1525 took 2.58 seconds
# Iter 217/1525 took 2.22 seconds
# Iter 218/1525 took 2.06 seconds
# Iter 219/1525 took 2.16 seconds
# Iter 220/1525 took 2.42 seconds
# Iter 221/1525 took 2.79 seconds
# Iter 222/1525 took 2.16 seconds
# Iter 223/1525 took 2.23 seconds
# Iter 224/1525 took 2.35 seconds
# Iter 225/1525 took 2.76 seconds
# Iter 226/1525 took 2.42 seconds
# Iter 227/1525 took 2.23 seconds
# Iter 228/1525 took 2.47 seconds
# Iter 229/1525 took 2.51 seconds
# Iter 230/1525 took 2.15 seconds
# Iter 231/1525 took 2.10 seconds
# Iter 232/1525 took 2.16 seconds
# Iter 233/1525 took 2.38 seconds
# Iter 234/1525 took 3.01 seconds
# Iter 235/1525 took 2.32 seconds
# Iter 236/1525 took 2.11 seconds

# %% [markdown]
# ## 5. 快速评估 checkpoint
#
# 这里评估的是训练 wrapper 下的 reward/length，不等于 `scripts/evaluate.py` 的比赛完成时间。真正比赛评估还需要把 checkpoint 接到 controller 里。
#
# 这个评估循环不调用 render，适合 notebook/headless 环境。

# %%
eval_args = build_args(num_envs=1, jax_device="cpu", cuda=False)
device = torch_device(eval_args)
eval_env = make_envs(
    config=eval_args.config,
    num_envs=1,
    jax_device=eval_args.jax_device,
    torch_device=device,
    coefs=REWARD_KWARGS | {"n_obs": eval_args.n_obs},
)
agent = Agent(eval_env.single_observation_space.shape, eval_env.single_action_space.shape).to(device)
checkpoint = torch.load(MODEL_PATH, map_location=device)
agent.load_state_dict(checkpoint.get("model_state_dict", checkpoint))
agent.eval()

episode_rewards = []
episode_lengths = []
with torch.no_grad():
    for episode in range(3):
        obs, _ = eval_env.reset(seed=eval_args.seed + episode + 1)
        done = torch.zeros(1, dtype=torch.bool, device=device)
        ep_reward = 0.0
        steps = 0
        while not done.any() and steps < 1500:
            action, _, _, _ = agent.get_action_and_value(obs, deterministic=True)
            obs, reward, terminated, truncated, _ = eval_env.step(action)
            done = terminated | truncated
            ep_reward += reward[0].item()
            steps += 1
        episode_rewards.append(ep_reward)
        episode_lengths.append(steps)
        print(f"episode={episode + 1} reward={ep_reward:.2f} length={steps}")
eval_env.close()

print("mean reward:", float(np.mean(episode_rewards)))
print("mean length:", float(np.mean(episode_lengths)))

# %% [markdown]
# ## success note
#      model name                    success rate           time
# 1. ppo_level2_gatepass1024_final        75%
# 2. ppo_level2_safe_final                80%                5.0
